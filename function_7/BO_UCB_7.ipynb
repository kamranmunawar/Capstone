# %% [markdown]
# **Function 7:**
#
# Sometimes Lazy is Best. You are now optimising six hyper-parameters of a machine learning model. Note that it is a popular and frequently used model, so maybe you could search to see if anyone else has optisized it before?

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

from statistics import NormalDist
import itertools as it

# %%
f7_inputs = np.load("initial_inputs.npy")
f7_outputs = np.load("initial_outputs.npy")
f7_inputs_2 = np.load("initial_inputs2.npy")
f7_outputs_2 = np.load("initial_outputs2.npy")

# %%
f7_inputs = np.concatenate((f7_inputs, f7_inputs_2)) 
f7_inputs = np.concatenate((f7_inputs, np.array([[0.63626 , 0.749201, 0.1892  , 0.68919 , 0.593918, 0.199029]]))) 
f7_inputs = np.concatenate((f7_inputs, np.array([[0.368718, 0.581611, 0.450298, 0.514296, 0.368287, 0.298886]]))) 
f7_inputs = np.concatenate((f7_inputs, np.array([[0.060895, 0.501672, 0.251022, 0.221018, 0.450428, 0.750969]]))) 
f7_inputs = np.concatenate((f7_inputs, np.array([[0.531569, 0.712456, 0.129994, 0.411075, 0.641262, 0.863832]]))) 
f7_inputs = np.concatenate((f7_inputs, np.array([[0.055673, 0.489451, 0.245211, 0.215896, 0.413761, 0.440428]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.574342, 0.678895, 0.533896, 0.92418 , 0.554493, 0.523589]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.100001, 0.495555, 0.297777, 0.198888, 0.396666, 0.693333]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.088889, 0.493332, 0.282221, 0.205554, 0.403332, 0.695555]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.097778, 0.497777, 0.299999, 0.192221, 0.385554, 0.713333]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.699728, 0.60899 , 0.530807, 0.004961, 0.23617 , 0.606289]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.189374, 0.254933, 0.38873 , 0.226883, 0.365509, 0.859723]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.193819, 0.254933, 0.393174, 0.231327, 0.361065, 0.859723]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.039062, 0.040611, 0.422165, 0.057258, 0.711931, 0.146917]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.200485, 0.266044, 0.39984 , 0.237993, 0.354398, 0.848611]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.211596, 0.286044, 0.410951, 0.249104, 0.343286, 0.828611]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.222707, 0.306044, 0.422062, 0.260215, 0.332174, 0.808611]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.229373, 0.321599, 0.428728, 0.266881, 0.325507, 0.793055]])))
f7_inputs = np.concatenate((f7_inputs, np.array([[0.222706, 0.337154, 0.422061, 0.264658, 0.327729, 0.777499]])))

f7_outputs = np.concatenate((f7_outputs,f7_outputs_2)) 
f7_outputs = np.append(f7_outputs,0.6531409333073234)
f7_outputs = np.append(f7_outputs,0.8720881396978204)
f7_outputs = np.append(f7_outputs,1.159982626521815)
f7_outputs = np.append(f7_outputs,0.06394964228046124)
f7_outputs = np.append(f7_outputs,0.9892232332511364)
f7_outputs = np.append(f7_outputs,0.02270238658904679)
f7_outputs = np.append(f7_outputs,1.5980696671819323)
f7_outputs = np.append(f7_outputs,1.552462506402468)
f7_outputs = np.append(f7_outputs,1.5958875261823084)
f7_outputs = np.append(f7_outputs,0.31095147109238114)
f7_outputs = np.append(f7_outputs,2.1108344344203425)
f7_outputs = np.append(f7_outputs,2.141437825123243)
f7_outputs = np.append(f7_outputs,0.14128327861643816)
f7_outputs = np.append(f7_outputs,2.2404023030732505)
f7_outputs = np.append(f7_outputs,2.3917589697962973)
f7_outputs = np.append(f7_outputs,2.5103520273309883)
f7_outputs = np.append(f7_outputs,2.57198926677023)
f7_outputs = np.append(f7_outputs,2.5936857026275053)

# %%
X_max= f7_inputs[np.argmax((f7_outputs))]
print(X_max)
# Out:
# [0.222706 0.337154 0.422061 0.264658 0.327729 0.777499]

# %%
Y_max= f7_outputs[np.argmax((f7_outputs))]
print(Y_max)
# Out:
# 2.5936857026275053

# %%
x1 = np.linspace(0.222706-0.02, 0.222706+0.02, 10)
x2 = np.linspace(0.337154-0.02, 0.337154+0.02, 10)
x3 = np.linspace(0.422061-0.02, 0.422061+0.02, 10)
x4 = np.linspace(0.264658-0.02, 0.264658+0.02, 10)
x5 = np.linspace(0.327729-0.02, 0.327729+0.02, 10)
x6 = np.linspace(0.777499-0.02, 0.777499+0.02, 10)
X_grid = []
for i in range(len(x1)):
    for j in range(len(x2)):
        for k in range(len(x3)):
            for l in range(len(x4)):
                for m in range(len(x5)):
                    for n in range(len(x6)):
                        X_grid.append([x1[i], x2[j],x3[k],x4[l],x5[m],x6[n]])
X_grid = np.array(X_grid)
#0.222706 0.337154 0.422061 0.264658 0.327729 0.777499
#0.229373 0.321599 0.428728 0.266881 0.325507 0.793055
#0.222707 0.306044 0.422062 0.260215 0.332174 0.808611
#0.211596 0.286044 0.410951 0.249104 0.343286 0.828611
#0.200485 0.266044 0.39984  0.237993 0.354398 0.848611
#0.193819 0.254933 0.393174 0.231327 0.361065 0.859723
#0.19159697 0.25271152 0.39095255 0.22910573 0.36328738 0.86194604
#0.19159697 0.25271152 0.39095255 0.22910573 0.36328738 0.86194604
#0.100001  , 0.495555  , 0.297777  , 0.198888  , 0.396666  , 0.693333 
#[0.05789554, 0.49167222, 0.24742222, 0.21811844, 0.42042833, 0.73096984]

# %%
f7_inputs
# Out:
# array([[0.27262382, 0.32449536, 0.89710881, 0.83295115, 0.15406269,
#         0.79586362],
#        [0.54300258, 0.9246939 , 0.34156746, 0.64648585, 0.71844033,
#         0.34313266],
#        [0.09083225, 0.66152938, 0.06593091, 0.25857701, 0.96345285,
#         0.6402654 ],
#        [0.11886697, 0.61505494, 0.90581639, 0.8553003 , 0.41363143,
#         0.58523563],
#        [0.63021764, 0.8380969 , 0.68001305, 0.73189509, 0.52673671,
#         0.34842921],
#        [0.76491917, 0.25588292, 0.60908422, 0.21807904, 0.32294277,
#         0.09579366],
#        [0.05789554, 0.49167222, 0.24742222, 0.21811844, 0.42042833,
#         0.73096984],
#        [0.19525188, 0.07922665, 0.55458046, 0.17056682, 0.01494418,
#         0.10703171],
#        [0.64230298, 0.83687455, 0.02179269, 0.10148801, 0.68307083,
#         0.6924164 ],
#        [0.78994255, 0.19554501, 0.57562333, 0.07365919, 0.25904917,
#         0.05109986],
#        [0.52849733, 0.45742436, 0.36009569, 0.36204551, 0.81689098,
#         0.63747637],
#        [0.72261522, 0.01181284, 0.06364591, 0.16517311, 0.07924415,
#         0.35995166],
#        [0.07566492, 0.33450212, 0.13273274, 0.60831236, 0.91838592,
#         0.82233079],
#        [0.94245084, 0.37743962, 0.48612233, 0.22879108, 0.08263175,
#         0.71195755],
#        [0.14864702, 0.03394336, 0.72880565, 0.31606646, 0.02176938,
#         0.51691776],
#        [0.81711239, 0.54816823, 0.10334758, 0.12436955, 0.72823482,
#         0.44967361],
#        [0.41762629, 0.06409998, 0.24566877, 0.5590408 , 0.19153138,
#         0.25464092],
#        [0.72628566, 0.46489581, 0.92457051, 0.8072454 , 0.6354384 ,
#         0.14341787],
#        [0.31981043, 0.52009759, 0.29067775, 0.87670668, 0.49503469,
#         0.6190825 ],
#        [0.87987128, 0.39796199, 0.00363456, 0.95699064, 0.26451373,
#         0.11486924],
#        [0.54124078, 0.63140314, 0.03190205, 0.44998156, 0.79865282,
#         0.63370429],
#        [0.22634792, 0.11502581, 0.82474966, 0.94538372, 0.90531153,
#         0.95101392],
#        [0.68685257, 0.04101721, 0.00757301, 0.285009  , 0.69156848,
#         0.6555429 ],
#        [0.17597754, 0.6244165 , 0.29554198, 0.46955276, 0.09776977,
#         0.72814108],
#        [0.88164674, 0.20445019, 0.41447436, 0.42038468, 0.26491501,
#         0.73066019],
#        [0.06661051, 0.52804507, 0.8160952 , 0.96101714, 0.08650933,
#         0.77778822],
#        [0.93246638, 0.48881189, 0.25860774, 0.95624344, 0.19042781,
#         0.51985176],
#        [0.84686697, 0.14242917, 0.06066859, 0.75629213, 0.5523983 ,
#         0.08130609],
#        [0.80628208, 0.32412237, 0.72607601, 0.14871213, 0.7193764 ,
#         0.36288398],
#        [0.47682313, 0.34094195, 0.01433523, 0.88013956, 0.9986547 ,
#         0.07966402],
#        [0.5533924 , 0.94265688, 0.37843995, 0.81644951, 0.30724102,
#         0.68667292],
#        [0.57767921, 0.77666698, 0.49167411, 0.8109403 , 0.2573919 ,
#         0.3111875 ],
#        [0.59949888, 0.87032335, 0.07862039, 0.8774701 , 0.44857133,
#         0.14032067],
#        [0.34391181, 0.16237337, 0.64747514, 0.33306226, 0.58985232,
#         0.34861981],
#        [0.25025126, 0.50258132, 0.86529474, 0.3948412 , 0.57668213,
#         0.22758252],
#        [0.38041208, 0.49217965, 0.16343703, 0.34501486, 0.00249229,
#         0.72742987],
#        [0.7000382 , 0.24792505, 0.99685626, 0.78816919, 0.4212353 ,
#         0.24110836],
#        [0.27215304, 0.36229447, 0.14792418, 0.98929021, 0.6172454 ,
#         0.90575561],
#        [0.98596285, 0.56551037, 0.0336468 , 0.81835521, 0.06473044,
#         0.29100716],
#        [0.10557451, 0.53066877, 0.70973029, 0.38713039, 0.377642  ,
#         0.68745292],
#        [0.41965144, 0.10239981, 0.65162054, 0.13551419, 0.17390985,
#         0.2449025 ],
#        [0.38333381, 0.48490161, 0.02330837, 0.31080082, 0.40659607,
#         0.37986672],
#        [0.64234772, 0.62485994, 0.59955676, 0.69695586, 0.58430151,
#         0.62741632],
#        [0.25112425, 0.02864035, 0.57442658, 0.30767792, 0.12493266,
#         0.81482005],
#        [0.67553455, 0.82278286, 0.56616623, 0.76746994, 0.94375052,
#         0.17817038],
#        [0.28944287, 0.66217003, 0.77907406, 0.67926704, 0.75774697,
#         0.19114322],
#        [0.2641496 , 0.33834387, 0.02791976, 0.79138507, 0.53999442,
#         0.03078242],
#        [0.72853841, 0.66131919, 0.82160388, 0.84709947, 0.51182809,
#         0.87821668],
#        [0.89376992, 0.0495654 , 0.37882925, 0.08810275, 0.20628684,
#         0.33004916],
#        [0.72124889, 0.42033325, 0.52594238, 0.29409231, 0.75095604,
#         0.00824324],
#        [0.02217805, 0.36399255, 0.40746356, 0.76190553, 0.84288594,
#         0.20669374],
#        [0.01173165, 0.79725639, 0.19069447, 0.61651098, 0.92391729,
#         0.54878971],
#        [0.07440619, 0.73607083, 0.11969825, 0.56493241, 0.02357042,
#         0.81937945],
#        [0.34817805, 0.10388219, 0.37486701, 0.91807747, 0.2251307 ,
#         0.55431265],
#        [0.35905913, 0.42182687, 0.88257684, 0.99104029, 0.57366693,
#         0.71468722],
#        [0.74989625, 0.77315963, 0.93679838, 0.6745058 , 0.41011799,
#         0.52921798],
#        [0.17906201, 0.97780095, 0.34230596, 0.9270413 , 0.35441174,
#         0.35621829],
#        [0.20131011, 0.20614847, 0.76968778, 0.33429616, 0.4874355 ,
#         0.13151584],
#        [0.19159697, 0.25271152, 0.39095255, 0.22910573, 0.36328738,
#         0.86194604],
#        [0.3666046 , 0.8950202 , 0.25725146, 0.74359107, 0.90913351,
#         0.88113057],
#        [0.63626   , 0.749201  , 0.1892    , 0.68919   , 0.593918  ,
#         0.199029  ],
#        [0.368718  , 0.581611  , 0.450298  , 0.514296  , 0.368287  ,
#         0.298886  ],
#        [0.060895  , 0.501672  , 0.251022  , 0.221018  , 0.450428  ,
#         0.750969  ],
#        [0.531569  , 0.712456  , 0.129994  , 0.411075  , 0.641262  ,
#         0.863832  ],
#        [0.055673  , 0.489451  , 0.245211  , 0.215896  , 0.413761  ,
#         0.440428  ],
#        [0.574342  , 0.678895  , 0.533896  , 0.92418   , 0.554493  ,
#         0.523589  ],
#        [0.100001  , 0.495555  , 0.297777  , 0.198888  , 0.396666  ,
#         0.693333  ],
#        [0.088889  , 0.493332  , 0.282221  , 0.205554  , 0.403332  ,
#         0.695555  ],
#        [0.097778  , 0.497777  , 0.299999  , 0.192221  , 0.385554  ,
#         0.713333  ],
#        [0.699728  , 0.60899   , 0.530807  , 0.004961  , 0.23617   ,
#         0.606289  ],
#        [0.189374  , 0.254933  , 0.38873   , 0.226883  , 0.365509  ,
#         0.859723  ],
#        [0.193819  , 0.254933  , 0.393174  , 0.231327  , 0.361065  ,
#         0.859723  ],
#        [0.039062  , 0.040611  , 0.422165  , 0.057258  , 0.711931  ,
#         0.146917  ],
#        [0.200485  , 0.266044  , 0.39984   , 0.237993  , 0.354398  ,
#         0.848611  ],
#        [0.211596  , 0.286044  , 0.410951  , 0.249104  , 0.343286  ,
#         0.828611  ],
#        [0.222707  , 0.306044  , 0.422062  , 0.260215  , 0.332174  ,
#         0.808611  ],
#        [0.229373  , 0.321599  , 0.428728  , 0.266881  , 0.325507  ,
#         0.793055  ],
#        [0.222706  , 0.337154  , 0.422061  , 0.264658  , 0.327729  ,
#         0.777499  ]])

# %%
f7_outputs
# Out:
# array([6.04432696e-01, 5.62753067e-01, 7.50323668e-03, 6.14243025e-02,
#        2.73046801e-01, 8.37465723e-02, 1.36496830e+00, 9.26449549e-02,
#        1.78695987e-02, 3.35649360e-02, 7.35163042e-02, 2.06309698e-01,
#        8.82563400e-03, 2.68400317e-01, 6.11525528e-01, 1.47981826e-02,
#        2.74892508e-01, 6.67632469e-02, 4.21183545e-02, 2.70146502e-03,
#        1.82090730e-02, 7.01602756e-03, 1.00506611e-01, 4.75395516e-01,
#        6.75141631e-01, 5.16457219e-01, 3.77747962e-03, 3.13433331e-03,
#        2.13425228e-02, 9.54111589e-02, 1.92262369e-02, 3.63302431e-01,
#        5.54078747e-01, 5.03285693e-01, 3.78578840e-01, 3.51420597e-01,
#        2.18384946e-02, 2.74181505e-03, 2.84503825e-03, 1.42061766e+00,
#        4.00914794e-01, 7.63154709e-01, 5.41883328e-02, 1.48980895e+00,
#        4.34444521e-01, 1.08014511e+00, 1.28917937e-01, 1.37702296e-01,
#        1.83158802e-01, 4.76459379e-02, 3.76226779e-02, 1.27204165e-02,
#        7.60433460e-02, 5.57235508e-02, 6.43550690e-02, 4.80363915e-02,
#        8.92795371e-02, 1.92032779e-01, 2.11469067e+00, 2.14979269e-03,
#        6.53140933e-01, 8.72088140e-01, 1.15998263e+00, 6.39496423e-02,
#        9.89223233e-01, 2.27023866e-02, 1.59806967e+00, 1.55246251e+00,
#        1.59588753e+00, 3.10951471e-01, 2.11083443e+00, 2.14143783e+00,
#        1.41283279e-01, 2.24040230e+00, 2.39175897e+00, 2.51035203e+00,
#        2.57198927e+00, 2.59368570e+00])

# %%
x_input = f7_inputs
y_input = f7_outputs

noise_assumption = 1e-10
rbf_lengthscale = 0.1
beta = 0.001

variable_value = np.linspace(0.001, 0.09, 10)
#variable_value = np.linspace(0.001, 0.09, 10)
#variable_value = np.linspace(0.1, 0.9, 100)
#variable_value = np.linspace(1, 3, 10)
#variable_value = np.linspace(1, 50, 100)
result = []
for i in range(len(variable_value)):
    #beta = variable_value[i]
    kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
    model = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption)
    model.fit(np.array(x_input),np.array(y_input))
    post_mean, post_std = model.predict(np.array(X_grid), return_std=True)
    post_mean, post_std = post_mean.squeeze(), post_std.squeeze()
    acquisition_function = post_mean + beta* post_std
    result.append([variable_value[i],[X_grid[np.argmax(acquisition_function)]]])

# %%
#[0.001,[array([0.06011776, 0.49389444, 0.24964444, 0.22034066, 0.41820611,0.44042833])]
#[0.001,[array([0.06011776, 0.49389444, 0.24964444, 0.22034066, 0.41820611,0.44042833])]
#[0.001,[array([0.05567332, 0.48945   , 0.2452    , 0.21589622, 0.41376166,0.44042833])]
#[0.001,[array([0.05567332, 0.48945   , 0.2452    , 0.21589622, 0.41376166,0.44042833])]
#[1.0, [array([0.080001, 0.515555, 0.277777, 0.218888, 0.416666, 0.673333])]],[1.2222222222222223,
#[0.001,[array([0.08888989, 0.49333278, 0.28222144, 0.20555467, 0.40333267, 0.69555522]

# %%
result
# Out:
# [[0.001,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]],
#  [0.010888888888888889,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]],
#  [0.020777777777777777,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]],
#  [0.030666666666666665,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]],
#  [0.04055555555555555,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]],
#  [0.050444444444444445,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]],
#  [0.06033333333333333,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]],
#  [0.07022222222222221,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]],
#  [0.0801111111111111,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]],
#  [0.09,
#   [array([0.22937267, 0.33493178, 0.42872767, 0.26243578, 0.32995122,
#           0.77972122])]]]
